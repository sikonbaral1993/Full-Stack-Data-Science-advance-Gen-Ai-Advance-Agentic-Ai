# %%
#other datatyp to int typecasting

# %%
int(3.5)
# Out:
# 3

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
int(2+3j) #we cant typecast complex to int data type
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 int(2+3j)
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'complex'

# %%
int('3.5')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 int('3.5')
#
# ValueError: invalid literal for int() with base 10: '3.5'

# %%
int('10')
# Out:
# 10

# %%
int('ten') #cant typecast  text string to int
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int('ten')
#
# ValueError: invalid literal for int() with base 10: 'ten'

# %%
int(2.4,2.5) # cant take 2 argument
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 int(2.4,2.5)
#
# TypeError: 'float' object cannot be interpreted as an integer

# %%
int(10, 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 int(10, 20)
#
# TypeError: int() can't convert non-string with explicit base

# %%
#Float to int

# %%
float(10)
# Out:
# 10.0

# %%
float(2+3j)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 float(2+3j)
#
# TypeError: float() argument must be a string or a real number, not 'complex'

# %%
float(True)
# Out:
# 1.0

# %%
float(False)
# Out:
# 0.0

# %%
Float('10')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 Float('10')
#
# NameError: name 'Float' is not defined

# %%
float('10.3')
# Out:
# 10.3

# %%
#Boolean

# %%
bool(12)
# Out:
# True

# %%
bool(10.3)
# Out:
# True

# %%
bool(1+2j)
# Out:
# True

# %%
bool("10")
# Out:
# True

# %%
bool('10.2')
# Out:
# True

# %%
bool(10.3,20.4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 bool(10.3,20.4)
#
# TypeError: bool expected at most 1 argument, got 2

# %%
bool(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 bool(10,20)
#
# TypeError: bool expected at most 1 argument, got 2

# %%
bool('ddkcbdk')
# Out:
# True

# %%
#Complex

# %%
complex(10)
# Out:
# (10+0j)

# %%
complex(10,20)
# Out:
# (10+20j)

# %%
complex(19.2)
# Out:
# (19.2+0j)

# %%
complex(11,22,33)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 complex(11,22,33)
#
# TypeError: complex() takes at most 2 arguments (3 given)

# %%
complex('10')
# Out:
# (10+0j)

# %%
complex(10,'20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 complex(10,'20')
#
# TypeError: complex() second arg can't be a string

# %%
complex('10',20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 complex('10',20)
#
# TypeError: complex() can't take second arg if first is a string

# %%
complex('ten')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 complex('ten')
#
# ValueError: complex() arg is a malformed string

# %%
complex(True,False)
# Out:
# (1+0j)

# %%
#String

# %%
str(123)
# Out:
# '123'

# %%
str(2.3)
# Out:
# '2.3'

# %%
str(True)
# Out:
# 'True'

# %%
str(False)
# Out:
# 'False'

# %%
str(1+2j)
# Out:
# '(1+2j)'

# %%
str(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 str(10,20)
#
# TypeError: str() argument 'encoding' must be str, not int

# %%
str('10','20')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 str('10','20')
#
# TypeError: decoding str is not supported
