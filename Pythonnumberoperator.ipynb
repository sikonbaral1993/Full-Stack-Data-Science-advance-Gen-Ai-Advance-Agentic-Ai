# %%
3
# Out:
# 3

# %%
8-3
# Out:
# 5

# %%
_
# Out:
# 5

# %%
_ +3
# Out:
# 8

# %%
_* 2
# Out:
# 16

# %%
12/4
# Out:
# 3.0

# %%
12//4
# Out:
# 3

# %%
4+5-10*3
# Out:
# -21

# %%
4+(5-10)*3
# Out:
# -11

# %%
4/(5-10)*3
# Out:
# -2.4000000000000004
