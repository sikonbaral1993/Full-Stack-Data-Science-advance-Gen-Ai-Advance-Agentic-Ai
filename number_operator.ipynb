# %%
3
# Out:
# 3

# %%
4
# Out:
# 4

# %%
3+4
# Out:
# 7

# %%
6+2
# Out:
# 8

# %%
6-2
# Out:
# 4

# %%
7*4
# Out:
# 28

# %%
28/4 #float division
# Out:
# 7.0

# %%
28//4 #int division
# Out:
# 7

# %%
3+4-6*3 #dmas
# Out:
# -11

# %%
5*4-(4+5) #bodmas
# Out:
# 11
