# %%
#binary

# %%
bin(30)
# Out:
# '0b11110'

# %%
bin(25)
# Out:
# '0b11001'

# %%
#Octal

# %%
oct(10)
# Out:
# '0o12'

# %%
oct(35)
# Out:
# '0o43'

# %%
#Hexadecimal

# %%
hex(13)
# Out:
# '0xd'

# %%
hex(34)
# Out:
# '0x22'

# %%
#Bitwise operator

# %%
#complement operator

# %%
~23 # itsalways store negative value +1
# Out:
# -24

# %%
~2333
# Out:
# -2334

# %%
#Bitwise And OR operator

# %%
12 & 14
# Out:
# 12

# %%
13 | 13
# Out:
# 13

# %%
#Xor

# %%
12 ^ 3
# Out:
# 15

# %%
14^144
# Out:
# 158

# %%
#Left shift operator

# %%
12 << 2
# Out:
# 48

# %%
13 << 2
# Out:
# 52

# %%
#right shift

# %%
10 >> 2
# Out:
# 2
