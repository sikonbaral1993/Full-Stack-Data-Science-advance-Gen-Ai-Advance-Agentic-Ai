# %%
'apple'
# Out:
# 'apple'

# %%
"Hello I am a python developr"
# Out:
# 'Hello I am a python developr'

# %%
"""Hi 
    my 
      name 
           is"""
# Out:
# 'Hi \n    my \n      name \n           is'

# %%
a= 5
a
# Out:
# 5

# %%
a= 6
A  # rule 1: variable is case sensitive
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 a= 6
# ----> 2 A
#
# NameError: name 'A' is not defined

# %%
2a= 30
2a #rule 2: variable doesnot start with digit
# Out:
#   Cell In[9], line 1
#     2a= 30
#     ^
# SyntaxError: invalid decimal literal

# %%
_a=4
_a
# Out:
# 4

# %%
@a= 4
@a #rule3: except _ variable does not accespt any special character
# Out:
#   Cell In[12], line 1
#     @a= 4
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
import =3
import #rule4: we cant declare keyward as variable
# Out:
#   Cell In[13], line 1
#     import =3
#            ^
# SyntaxError: invalid syntax

# %%
age = 50
age
# Out:
# 50

# %%
name ='sikon'
print(name)
# Out:
# sikon

# %%
#Storing and printing the value
a=30
print(a)
# Out:
# 30

# %%
#using variable in expression
a=5
b=3
c = a+b
print(c)
# Out:
# 8

# %%
#inaitial value
age =30
print(age)
#changeing the value
age =80
print (age)
# Out:
# 30
# 80

# %%
#concanating the string
fname = "sikon"
lname = "baral"
full_name= fname+ " " +lname
print(full_name)
# Out:
# sikon baral

# %%
#using variable in calculation
length=30
width= 40
area= length * width
print(area)
# Out:
# 1200

# %%
#keywards in python
#total 35 keyward
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']
