# %%
#Arithmatic operator

# %%
2+3
# Out:
# 5

# %%
3-2
# Out:
# 1

# %%
3*3
# Out:
# 9

# %%
6/2
# Out:
# 3.0

# %%
6%2
# Out:
# 0

# %%
#Asignment operator

# %%
x=2
x+=3
x
# Out:
# 5

# %%
x =4
x-=2
x
# Out:
# 2

# %%
x*=3
x
# Out:
# 6

# %%
#Relational operators(<, >, <=, >=, ==, !=)

# %%
a =5
b =6
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
#Logical operator(and,or,not)

# %%
a=5
b=4
a<8 and b>6
# Out:
# False

# %%
a<6 or b>6
# Out:
# True

# %%
x=True
not(x)
# Out:
# False

# %%
#Urany operator(-)

# %%
n=7
n
# Out:
# 7

# %%
-n
# Out:
# -7
