# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
i = 5
i
# Out:
# 5

# %%
type(i)
# Out:
# int

# %%
5=i
# Out:
#   Cell In[5], line 1
#     5=i
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
y=44.3
y
# Out:
# 44.3

# %%
type(y)
# Out:
# float

# %%
2e0
# Out:
# 2.0

# %%
2e1
# Out:
# 20.0

# %%
2e2
# Out:
# 200.0

# %%
2e3
# Out:
# 2000.0

# %%
-4e3
# Out:
# -4000.0

# %%
2E4
# Out:
# 20000.0

# %%
2.4E2
# Out:
# 240.0

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
true #T should be capital always
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 true
#
# NameError: name 'true' is not defined

# %%
True+False  #1+0=1
# Out:
# 1

# %%
None

# %%
none
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 none
#
# NameError: name 'none' is not defined

# %%
x =True
y = False
print(x + y)
print(x - y)
print (x * y)
print(y / x)
print (y // x)
# Out:
# 1
# 1
# 0
# 0.0
# 0

# %%
#complex
c = 10+20j
c
# Out:
# (10+20j)

# %%
type(c)
# Out:
# complex

# %%
print(c.real)
print(c.imag)
# Out:
# 10.0
# 20.0

# %%
x = 10+30j
y = 20+ 40j
z = x+y
print(z)
# Out:
# (30+70j)
