# %%
#LIST

# %%
l=[]
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l1=[1,2,3,4]
l1
# Out:
# [1, 2, 3, 4]

# %%
type(l1)
# Out:
# list

# %%
len(l1)
# Out:
# 4

# %%
l1.append(5)#it add value at last
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l1.append(6,7) #append() takes only one argument
l1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 l1.append(6,7) #append() takes only one argument
#       2 l1
#
# TypeError: list.append() takes exactly one argument (2 given)

# %%
#append()

# %%
#append() takes only one argument and add element in the last of list

# %%
l1.append(6)
l1.append(7)
l1

# %%
l1

# %%
l1.append(['a','b']) #nested list
l1

# %%
l2= [23,3.4,'a', 2+3j, True]
l2

# %%
print(len(l))
print(len(l1))
print(len(l2))

# %%
print(id(l))
print(id(l1))
print(id(l2))

# %%
print(type(l))
print(type(l1))
print(type(l2))

# %%
#List membership

# %%
l1

# %%
5 in (l1)

# %%
30 in (l1)

# %%
#copy()

# %%
l1

# %%
l3= l1.copy()
l3

# %%
print(id(l1))
print(id(l3))

# %%
print(l)
print(l1)
print(l2)
print(l3)

# %%
l3

# %%
len(l3)

# %%
# clear(): it will clear all elemeny from list

# %%
l3.clear()
l3

# %%
# delete the list

# %%
del l3

# %%
l3

# %%
#count() : it will return the occurance of a value

# %%
print(l)
print(l1)
print(l2)

# %%
l1.count(5)

# %%
l1

# %%
l1[:]

# %%
l1[-1]

# %%
l1[14]

# %%
l1

# %%
l1[4:]

# %%
l1[3:-1]

# %%
l1

# %%
l1[0:10:3]

# %%
l1

# %%
l1[::1]

# %%
l1[::2]

# %%
l1

# %%
l1[::-1]

# %%
l1[::-3]

# %%
l1[2:-3]

# %%
l1[2::-1]

# %%
print(l)
print(l1)
print(l2)

# %%
l1[1]

# %%
l1[1]=23
l1

# %%
print(l)
print(l1)
print(l2)

# %%
#extend() : it is used to merged two list

# %%
l.extend(l1)
l

# %%
print(l)
print(l1)
print(l2)

# %%
print(id(l))
print(id(l1))
print(id(l2))

# %%
#index(): it will print first occurace of index value

# %%
l1.index(4)

# %%
l1.append(4)
l1

# %%
l1.index(4)

# %%
l1.index(1)

# %%
l1.index(100)

# %%
#insert() : it will insert element before object

# %%
l1

# %%
l1.insert(2,22)# here 2 is index no and 22 is value
l1

# %%
#pop(): it remove the last value

# %%
l1.pop() # it will remove only one element at a time from last
l1

# %%
l1

# %%
l1.pop(3) #to remove the particular index we need to pass the index no
l1

# %%
#remove() : it removes based on value

# %%
l1

# %%
l1.remove(23)
l1

# %%
l1

# %%
#reverse() : it is used to reversed a list

# %%
l1.reverse()
l1

# %%
l2

# %%
l2 .reverse()
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 l2 .reverse()
#       2 l2
#
# NameError: name 'l2' is not defined

# %%
#Sorting : it always works in similar datatype

# %%
l1
# Out:
# [1, 2, 3, 4, 5]

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l4 =[3,5,3,2,6,7,1,9]
l4
# Out:
# [3, 5, 3, 2, 6, 7, 1, 9]

# %%
l4.sort()
l4
# Out:
# [1, 2, 3, 3, 5, 6, 7, 9]

# %%
l4.sort(reverse= True)
l4
# Out:
# [9, 7, 6, 5, 3, 3, 2, 1]

# %%
#Parameter tuning

# %%
l4
# Out:
# [9, 7, 6, 5, 3, 3, 2, 1]

# %%
l4.sort() #it will print the default value
l4
# Out:
# [1, 2, 3, 3, 5, 6, 7, 9]

# %%
#Hyper parameter tuning

# %%
l4
# Out:
# [1, 2, 3, 3, 5, 6, 7, 9]

# %%
l4.sort(reverse= True) #it will print custom values
l4
# Out:
# [9, 7, 6, 5, 3, 3, 2, 1]

# %%
#Nested index(index of index)

# %%
l4
# Out:
# [9, 7, 6, 5, 3, 3, 2, 1]

# %%
l4.append('Sikon')
l4
# Out:
# [9, 7, 6, 5, 3, 3, 2, 1, 'Sikon']

# %%
l4[4]
# Out:
# 3

# %%
l4[8][2]
# Out:
# 'k'

# %%
l4.append(1+2j)
l4
# Out:
# [9, 7, 6, 5, 3, 3, 2, 1, 'Sikon', (1+2j)]

# %%
l4[9][2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 l4[9][2]
#
# TypeError: 'complex' object is not subscriptable

# %%
l4.append(44)
l4
# Out:
# [9, 7, 6, 5, 3, 3, 2, 1, 'Sikon', (1+2j), 44]

# %%
l4[10][1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 l4[10][1]
#
# TypeError: 'int' object is not subscriptable

# %%
for i in l4:
    print(i)
# Out:
# 9
# 7
# 6
# 5
# 3
# 3
# 2
# 1
# Sikon
# (1+2j)
# 44

# %%
for i in enumerate(l4):
    print(i)
# Out:
# (0, 9)
# (1, 7)
# (2, 6)
# (3, 5)
# (4, 3)
# (5, 3)
# (6, 2)
# (7, 1)
# (8, 'Sikon')
# (9, (1+2j))
# (10, 44)

# %%
#all/any

# %%
l5 = [1,2,3,4,5]
l5
# Out:
# [1, 2, 3, 4, 5]

# %%
all(l5)
# Out:
# True

# %%
any(l5)
# Out:
# True

# %%
l5.append(0)
l5
# Out:
# [1, 2, 3, 4, 5, 0]

# %%
all(l5)
# Out:
# False

# %%
any(l5)
# Out:
# True

# %%
l6 =[]
l6
# Out:
# []

# %%
all(l6)
# Out:
# True

# %%
any(l6)
# Out:
# False
