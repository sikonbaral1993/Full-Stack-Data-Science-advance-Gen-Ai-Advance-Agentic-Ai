# %% [markdown]
# Tuple()

# %%
t =()
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t1=(10,30,40)
t1
# Out:
# (10, 30, 40)

# %%
t2 = (1, 5,2.3, 'sikan', 1+4j, True)
t2
# Out:
# (1, 5, 2.3, 'sikan', (1+4j), True)

# %%
print(t)
print(t1)
print(t2)
# Out:
# ()
# (10, 30, 40)
# (1, 5, 2.3, 'sikan', (1+4j), True)

# %%
t2.count(5)
# Out:
# 1

# %%
t2.index(2.3)
# Out:
# 2

# %%
t1.append(11)
t1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 t1.append(11)
#       2 t1
#
# AttributeError: 'tuple' object has no attribute 'append'

# %%
t1.pop()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 t1.pop()
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t1.pop(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 t1.pop(0)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
t1
# Out:
# (10, 30, 40)

# %%
t1[0]
# Out:
# 10

# %%
t1[0] = 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 t1[0] = 5
#
# TypeError: 'tuple' object does not support item assignment

# %%
t3= t1* 2
t3
# Out:
# (10, 30, 40, 10, 30, 40)
